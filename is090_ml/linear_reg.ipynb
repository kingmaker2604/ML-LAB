# %%
import matplotlib.pyplot as mat
import pandas as pd

# %%
df=pd.read_csv("carspeed.csv")
df.head()
mat.scatter(df['x'],df['y'])
mat.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-01256d5bf094> in <module>
#       1 df=pd.read_csv("carspeed.csv")
#       2 df.head()
# ----> 3 mat.scatter(df['x'],df['y'])
#       4 mat.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2893         verts=verts, edgecolors=edgecolors,
#    2894         plotnonfinite=plotnonfinite,
# -> 2895         **({"data": data} if data is not None else {}), **kwargs)
#    2896     sci(__ret)
#    2897     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...

# %%
from scipy import stats
slope,intcep,r,p,std_err=stats.linregress(x,y)
print("coefficient of the linear regression is:",r) 
def myfunc(x):
    return slope*x+intcep

mymod=list(map(myfunc,x))

mat.scatter(x,y)
mat.plot(x,mymod)
mat.show()
speed=myfunc(10)
print("speed of 10 yewar old vehicle:",speed)
# Out:
# coefficient of the linear regression is: 0.2295552024677729
# speed of 10 yewar old vehicle: 80.12857142857143
