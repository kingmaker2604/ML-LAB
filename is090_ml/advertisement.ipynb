# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
def linreg(x,y):
    m,c,r,p,e=stats.linregress(x,y)
    print("slope",m)
    print("y intercept",c)
    Y=[]
    for i in x:
        k=m*i+c
        Y.append(k)
    print(Y)
    mse=mean_squared_error(y,Y)
    rms = sqrt(mean_squared_error(y, Y))
    print("mse:",mse)
    print("rmse:",rms)
    plt.scatter(x,y)
    plt.plot(x,Y,color="red")
    plt.show()

# %%
#TV VS SALES
linreg(df['TV'],df['sales'])
# Out:
# slope 0.0475366404330197
# y intercept 7.032593549127702
# ...

# %%
#RADIO VS SALES
linreg(df['radio'],df['sales'])
# Out:
# slope 0.20249578339243954
# y intercept 9.311638095158287
# ...

# %%
#NEWSPAPER VS SALES
linreg(df['newspaper'],df['sales'])
# Out:
# slope 0.05469309847227331
# y intercept 12.351407069278162
# ...
